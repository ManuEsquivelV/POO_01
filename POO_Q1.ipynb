# %% [markdown]
# 1.- Crea un diccionario que contenga 3 llaves que sean de tipo string y cuyos valores sean una lista que contenga 5 valores (3 numéricos y 2 flotantes).
#
# 2.- A partir del diccionario anterior, muestra a sus ítems. ¿Qué tipo de objeto se obtiene?
#
# 3.- Crea un panel de datos usando tu diccionario. Realiza tres segregaciones distintas.
#
# 4.- Realiza un breve análisis descriptivo de tu panel de datos. Explica los valores que obtienes.
#
# 5.- Realiza dos filtros de búsqueda sobre tu panel de datos.
#
# Texto de respuesta Pregunta 1
# Editor de texto enriquecido

# %%
diccionario = { "Messi": [900, 200.5, 300, 815.75, 500],
                "Ronaldo": [500, 100.2, 840, 182.5, 390.14],
                "Neymar": [700, 200, 150, 750.5, 250.2]}

import pandas as pd

# %%
diccionario.items()
# Out:
# dict_items([('Messi', [900, 200.5, 300, 815.75, 500]), ('Ronaldo', [500, 100.2, 840, 182.5, 390.14]), ('Neymar', [700, 200, 150, 750.5, 250.2])])

# %%
df = pd.DataFrame(diccionario)

# %%
df.rename(index={0: 'MinutosTemp 1', 1: 'MinutosTemp 2', 2: 'MinutosTemp 3', 3:'MinutosTemp 4', 4:'MinutosTemp 5'}, inplace = True)
df
# Out:
#                 Messi  Ronaldo  Neymar
# MinutosTemp 1  900.00   500.00   700.0
# MinutosTemp 2  200.50   100.20   200.0
# MinutosTemp 3  300.00   840.00   150.0
# MinutosTemp 4  815.75   182.50   750.5
# MinutosTemp 5  500.00   390.14   250.2

# %%
diccionario['Neymar']
# Out:
# [700, 200, 150, 750.5, 250.2]

# %%
df[["Messi","Ronaldo"]]
# Out:
#                 Messi  Ronaldo
# MinutosTemp 1  900.00   500.00
# MinutosTemp 2  200.50   100.20
# MinutosTemp 3  300.00   840.00
# MinutosTemp 4  815.75   182.50
# MinutosTemp 5  500.00   390.14

# %%
df.iloc[0:2]
# Out:
#                Messi  Ronaldo  Neymar
# MinutosTemp 1  900.0    500.0   700.0
# MinutosTemp 2  200.5    100.2   200.0

# %%
df.iloc[0]
# Out:
# Messi      900.0
# Ronaldo    500.0
# Neymar     700.0
# Name: MinutosTemp 1, dtype: float64

# %%
df.describe()
# Out:
#             Messi     Ronaldo      Neymar
# count    5.000000    5.000000    5.000000
# mean   543.250000  402.568000  410.140000
# std    308.239152  291.912031  290.377423
# min    200.500000  100.200000  150.000000
# 25%    300.000000  182.500000  200.000000
# 50%    500.000000  390.140000  250.200000
# 75%    815.750000  500.000000  700.000000
# max    900.000000  840.000000  750.500000

# %%
df_temporada = df.drop(columns=['Neymar'])
df4_5 = df_Ronaldo.iloc[1:2]
print("Jugadores con un más de 300 minutos jugados:")
print(df_temporada)

Ronaldo = df4_5["Ronaldo"].mean()
print(Ronaldo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-e268fb30c872> in <cell line: 2>()
#       1 df_temporada = df.drop(columns=['Neymar'])
# ----> 2 df4_5 = df_Ronaldo.iloc[1:2]
#       3 print("Jugadores con un más de 300 minutos jugados:")
#       4 print(df_temporada)
#       5
#
# NameError: name 'df_Ronaldo' is not defined

# %%
for clave, valor in diccionario.items():
    print(f"Llave: {clave}, Valor: {valor}")
# Out:
# Llave: Messi, Valor: [10, 20.5, 30, 15.75, 5]
# Llave: Ronaldo, Valor: [5, 10.2, 8, 12.5, 3.14]
# Llave: Neymar, Valor: [100, 200, 150, 75.5, 25.2]
